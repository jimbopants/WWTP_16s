# %%
# Check whether unpaired data files data exist in pairs so that they can be paired. Fuck that sounds stupid. 

import os
import glob

fastq_files = glob.glob("/Users/jimbo/Desktop/6.9.15_seq_data/unpaired/*")
index = 0

for name in fastq_files:
    leaf = name.split("/")[-1]
    if index==0:
        file1 = leaf
        index+=1
    if index==1:
        index=0
        file2 = leaf
        if file1[0:9]!=file2[0:9]:
            print file1, file2
        else: 
            pass
            #print "ok!"
    #print leaf


#glob the files, while files, if index-0, file1 = file, index+=1, if index=1, file2=file, index=0, if file1[start] != file2[start], print file1, file2

# %%
# Map file creation:
# I want a map file with all of my data - seq #s, Plant-Date, Filename root, Barcode, and initial name (JGx-xy)

# %%
# This cell adds the dates in two formats mm/dd/yy, 
# and Month to an existing map file with the date in mm/dd format

import pandas as pd


df = pd.read_excel("../map/map_v1_corrected.xlsx")
df["Month"] = pd.Series(" 1", index=df.index)
#print df
dfreact = df.Reactor
#print dfreact.unique()

dfdate = df.Date
print dfdate

# I want to split the date, check month, and then concat the date + 14 or 15 to a new column
# then based on the month (split[0]) I want to add a new value to the month column based on a dict of months
# Then I want to skip the RAR and NaN samples



# Adding month as a categorical value
months = {'1': "January",
          '2': "February",
          '3': "March",
          '4': "April",
          '5': "May",
          '8': 'August',
          '10': "October",
          '11': "November",
          '12': "December",
          }
print months

for date in dfdate[:-1]: # Ignore the NaN value for the NTC.
    if type(date)!="float":
        if "/" in date:
            x=date.split("/")
            row = df[df.Date==date].index # Super hacky way of getting index of a column value match.
            df.ix[row, "Month"] = months[x[0]]
# Out:
# 0      3/5
# 1     3/12
# 2     3/20
# 3     3/26
# 4     1/29
# 5      2/5
# 6     2/20
# 7     2/26
# 8      3/5
# 9     3/12
# 10    3/20
# 11    3/26
# 12    1/29
# 13     2/5
# 14    2/20
# ...
# 132    4/16
# 133    4/16
# 134    4/23
# 135    4/23
# 136    4/23
# 137    4/23
# 138    4/23
# 139    4/23
# 140    4/30
# 141    4/30
# 142    4/30
# 143    4/30
# 144    4/30
# 145    4/30
# 146     NaN
# Name: Date, Length: 147, dtype: object
# {'1': 'January', '10': 'October', '3': 'March', '2': 'February', '5': 'May', '4': 'April', '11': 'November', '8': 'August', '12': 'December'}
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# <type 'unicode'>
# 117   JG2.F3      CACAGTGATG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 118   JG2.G3      CGAGCTAGCA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 119   JG2.H3      GAGACTATGC  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 120   JG2.A4      CAGAGCTAGT  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 121   JG2.B4      CGCAGAGCAT  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 122   JG2.C4      TGTACAGCGA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 123   JG2.D4      ACGTCAGTAT  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 124   JG2.E4      TCACAGCATA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 125   JG2.F4      ACTGCGTGTC  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 126   JG2.G4      CGATCGACTG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 127   JG2.H4      GCGAGATGTA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 128   JG2.A5      CTGATGCAGA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 129   JG2.B5      GTGACGTACG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 130   JG2.C5      CGACGCTGAT  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 131   JG2.D5      CTACGATCAG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 132   JG2.E5      GCACTAGACA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 133   JG2.F5      CTAGCAGATG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 134   JG2.A6      ACGTATCATC  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 135   JG2.B6      AGTATCGTAC  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 136   JG2.C6      GATACACTGA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 137   JG2.D6      GACTAGTCAG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 138   JG2.E6      GATGACTACG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 139   JG2.F6      CAGAGAGTCA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 140   JG2.A7      ACTCGATAGT  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 141   JG2.B7      GACGATCGCA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 142   JG2.C7      TCATCATGCG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 143   JG2.D7      ACATGTCTGA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 144   JG2.E7      AGTCATCGCA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 145   JG2.F7      TAGCATACAG  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
# 146  JG2.NTC      CACGAGATGA  GTGCCAGCMGCCGCGGTAA  GGACTACHVGGGTATCTAAT
#
#     Description Reactor   Date     Month
# 0        H1-3/5      H1    3/5     March
# 1       H1-3/12      H1   3/12     March
# 2       H1-3/20      H1   3/20     March
# 3       H1-3/26      H1   3/26     March
# 4       H1-1/29      H1   1/29   January
# 5        H1-2/5      H1    2/5  February
# 6       H1-2/20      H1   2/20  February
# 7       H1-2/26      H1   2/26  February
# 8        H7-3/5      H7    3/5     March
# 9       H7-3/12      H7   3/12     March
# 10      H7-3/20      H7   3/20     March
# 11      H7-3/26      H7   3/26     March
# 12      H7-1/29      H7   1/29   January
# 13       H7-2/5      H7    2/5  February
# 14      H7-2/20      H7   2/20  February
# 15      H7-2/26      H7   2/26  February
# 16       EN-3/5      EN    3/5     March
# 17      EN-3/12      EN   3/12     March
# 18      EN-3/20      EN   3/20     March
# 19      EN-3/26      EN   3/26     March
# 20      EN-1/29      EN   1/29   January
# 21       EN-2/5      EN    2/5  February
# 22      EN-2/20      EN   2/20  February
# 23      EN-2/26      EN   2/26  February
# 24       ES-3/5      ES    3/5     March
# 25      ES-3/12      ES   3/12     March
# 26      ES-3/20      ES   3/20     March
# 27      ES-3/26      ES   3/26     March
# 28      ES-1/29      ES   1/29   January
# 29       ES-2/5      ES    2/5  February
# ..          ...     ...    ...       ...
# 117    OB-10/15      OB  10/15   October
# 118    H1-10/22      H1  10/22   October
# 119    H7-10/22      H7  10/22   October
# 120     K3-10/1      K3   10/1   October
# 121    K3-10/29      K3  10/29   October
# 122   OB5-10/29      OB  10/29   October
# 123       RAR-1     RAR      1         1
# 124       RAR-2     RAR      2         1
# 125       RAR-3     RAR      3         1
# 126    K3-10/22      K3  10/22   October
# 127   OB5-10/22      OB  10/22   October
# 128     H1-4/16      H1   4/16     April
# 129     H7-4/16      H7   4/16     April
# 130    EN1-4/16      EN   4/16     April
# 131     ES-4/16      ES   4/16     April
# 132    K3A-4/16      K3   4/16     April
# 133   OB5A-4/16      OB   4/16     April
# 134     H1-4/23      H1   4/23     April
# 135     H7-4/23      H7   4/23     April
# 136    EN1-4/23      EN   4/23     April
# 137     ES-4/23      ES   4/23     April
# 138    K3A-4/23      K3   4/23     April
# 139   OB5A-4/23      OB   4/23     April
# 140     H1-4/30      H1   4/30     April
# 141     H7-4/30      H7   4/30     April
# 142    EN1-4/30      EN   4/30     April
# 143     ES-4/30      ES   4/30     April
# 144    K3A-4/30      K3   4/30     April
# 145   OB5A-4/30      OB   4/30     April
# 146         NTC      NT    NaN         1
#
# [147 rows x 8 columns]

# %%
pwd
# Out:
# u'/Users/jimbo/Desktop/6.9.15_seq_data/Code'
